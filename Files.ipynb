# %% [markdown]
# <a href="https://colab.research.google.com/github/Sagar25-prac/Python_files/blob/main/Files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import shutil

# %%
print('-os:')
print(dir(os))
# Out:
# -os:
# ...

# %%
print('-shutil:')
print(dir(shutil))
# Out:
# -shutil:
# ...

# %%
import psutil

# %%
print(':psutil:')
print(dir(psutil))
# Out:
# :psutil:
# ...
